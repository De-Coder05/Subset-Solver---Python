# %% [markdown]
# <a href="https://colab.research.google.com/github/De-Coder05/Subset-Solver-Python/blob/main/Subset_Solver_Problem_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random as r
a = set([-12, -3, -6, 7, 2, -2, 6, 3, 9, -7, -5, -8, 1, 11, -9, -4])
setSize = 5
resultList = set()
iterations = 10000
for i in range(iterations):
    random = r.sample(sorted(a),setSize)
    random.sort()
    if sum(random) == 0:
        resultList.add(tuple(random))
for i in resultList:
	print (i)
print ("\nTotal Sets: ", len(resultList))
# Out:
# (-12, -3, 2, 6, 7)
# (-9, -3, 2, 3, 7)
# (-12, -6, 1, 6, 11)
# (-6, -5, 1, 3, 7)
# (-8, -4, -3, 6, 9)
# (-9, -7, -4, 9, 11)
# (-9, -2, 2, 3, 6)
# (-6, -4, 1, 3, 6)
# (-5, -3, -2, 3, 7)
# (-8, -6, -3, 6, 11)
# (-6, -5, -2, 2, 11)
# (-9, -7, -2, 7, 11)
# (-5, -3, -2, 1, 9)
# (-12, -8, 3, 6, 11)
# (-9, -5, -2, 7, 9)
# (-12, -7, 3, 7, 9)
# (-12, -5, 2, 6, 9)
# (-5, -4, -3, 3, 9)
# (-7, -6, -4, 6, 11)
# (-8, -5, -3, 7, 9)
# (-12, -6, 3, 6, 9)
# (-12, -4, 1, 6, 9)
# (-7, -4, -2, 6, 7)
# (-9, -8, 2, 6, 9)
# (-7, -4, -3, 3, 11)
# (-5, -4, 1, 2, 6)
# (-9, -2, 1, 3, 7)
# (-12, -2, 1, 6, 7)
# (-12, -3, -2, 6, 11)
# (-7, -4, 1, 3, 7)
# (-7, -6, 1, 3, 9)
# (-6, -4, 1, 2, 7)
# (-12, 1, 2, 3, 6)
# (-12, -3, 1, 3, 11)
# (-7, -3, -2, 3, 9)
# (-4, -2, 1, 2, 3)
# (-6, -5, 2, 3, 6)
# (-6, -3, 1, 2, 6)
# (-9, -8, 1, 7, 9)
# (-9, -6, -5, 9, 11)
# (-6, -4, -2, 3, 9)
# (-8, -5, 1, 3, 9)
# (-7, -5, 1, 2, 9)
# (-9, -5, 1, 6, 7)
# (-9, -6, -2, 6, 11)
# (-6, -3, -2, 2, 9)
# (-12, -4, 3, 6, 7)
# ...
